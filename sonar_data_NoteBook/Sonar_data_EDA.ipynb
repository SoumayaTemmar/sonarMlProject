# %% [markdown]
# ## Sonar data EDA
# in this notebook we will be analysing the sonar data for rock/mine classification.
#
# this dataset was downloaded from kaggle:
#
# url: https://www.kaggle.com/datasets/mahmudulhaqueshawon/sonar-data

# %% [markdown]
# Each row in the CSV file likely represents a single measurement or observation, while the columns
#
# represent different parameters or features.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## DATA exploration

# %%
sonar_data = pd.read_csv('data/sonar data.csv', header=None)
sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
sonar_data.shape
# Out:
# (208, 61)

# %%
sonar_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    float64
#  1   1       208 non-null    float64
#  2   2       208 non-null    float64
#  3   3       208 non-null    float64
#  4   4       208 non-null    float64
#  5   5       208 non-null    float64
#  6   6       208 non-null    float64
#  7   7       208 non-null    float64
#  8   8       208 non-null    float64
#  9   9       208 non-null    float64
#  10  10      208 non-null    float64
#  11  11      208 non-null    float64
#  12  12      208 non-null    float64
#  13  13      208 non-null    float64
#  14  14      208 non-null    float64
#  15  15      208 non-null    float64
#  16  16      208 non-null    float64
#  17  17      208 non-null    float64
#  18  18      208 non-null    float64
#  19  19      208 non-null    float64
# ...

# %%
sonar_data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# we can see that all the features are of type float, no issues , we also have one column of type obj which is the output column, the one to predict
#
# in terms of shape we have 208 entries, it's a small dataset, but still woth investigating,
#
# no null values, the data is likely clean

# %%
sonar_data.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %% [markdown]
# we can clearly see that the mean != median, & the max values are extreamly high if we compare them to the min(spread data).also analysing the Q3 with the max, we  can say that the features are skewed
#
# for example, (f1): max -> 0.137100 , Q3 -> 0.035550 which means 75% of the data are less than 0.0355550 while the max is 0.137100, ---> most values are small, but a few large ones stretch the tail to the right.
#
# stds differ across features ---> we need to standardize

# %%
# class distribution

sns.countplot(x=60, data=sonar_data)
plt.title("Class Distribution")
plt.show()

sonar_data[60].value_counts(normalize=True)
# Out:
# 60
# M    0.533654
# R    0.466346
# Name: proportion, dtype: float64

# %% [markdown]
# our data is balanced

# %% [markdown]
# ## Visualization

# %%
sonar_data.columns = [f"Feature_{i}" for i in range(60)] + ["Target"]
sonar_data.head()
# Out:
#    Feature_0  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0     0.0200     0.0371     0.0428     0.0207     0.0954     0.0986
# 1     0.0453     0.0523     0.0843     0.0689     0.1183     0.2583
# 2     0.0262     0.0582     0.1099     0.1083     0.0974     0.2280
# 3     0.0100     0.0171     0.0623     0.0205     0.0205     0.0368
# 4     0.0762     0.0666     0.0481     0.0394     0.0590     0.0649
#
#    Feature_6  Feature_7  Feature_8  Feature_9  ...  Feature_51  Feature_52  \
# 0     0.1539     0.1601     0.3109     0.2111  ...      0.0027      0.0065
# 1     0.2156     0.3481     0.3337     0.2872  ...      0.0084      0.0089
# 2     0.2431     0.3771     0.5598     0.6194  ...      0.0232      0.0166
# 3     0.1098     0.1276     0.0598     0.1264  ...      0.0121      0.0036
# 4     0.1209     0.2467     0.3564     0.4459  ...      0.0031      0.0054
#
#    Feature_53  Feature_54  Feature_55  Feature_56  Feature_57  Feature_58  \
# ...

# %%
# select the most informative features to plot(visualize), we cannot plot all 60
class_mean = sonar_data.groupby("Target").mean().T
class_mean.head()
# Out:
# Target            M         R
# Feature_0  0.034989  0.022498
# Feature_1  0.045544  0.030303
# Feature_2  0.050720  0.035951
# Feature_3  0.064768  0.041447
# Feature_4  0.086715  0.062028

# %%
# get features that differ the most between R and M → potentially discriminative

top_features = (class_mean['M'] - class_mean['R']).abs().sort_values(ascending=False)
top_features.head(10)
# Out:
# Feature_35    0.142157
# Feature_20    0.125156
# Feature_34    0.117977
# Feature_19    0.117713
# Feature_10    0.114868
# Feature_11    0.109870
# Feature_21    0.103036
# Feature_44    0.102913
# Feature_36    0.100296
# Feature_9     0.091697
# dtype: float64

# %%
top_three = top_features.head(3).index

for feature in top_three:
   fig, axes = plt.subplots(1,2,figsize=(10,4))
   sns.histplot(data=sonar_data, x=feature, hue='Target', kde=True, ax=axes[0])
   axes[0].set_title(f'Histogram of {feature}')
    
   sns.boxplot(x='Target', y=feature, data=sonar_data, ax=axes[1])
   axes[1].set_title(f'Boxplot of {feature}')
   
   plt.show()
# Out:
# c:\Users\lmokh phone\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\lmokh phone\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\lmokh phone\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# correlation test
plt.figure(figsize=(12, 10))
sns.heatmap(sonar_data.iloc[:, :-1].corr(), cmap='coolwarm', center=0)
plt.title("Feature Correlation Heatmap")
plt.show()
